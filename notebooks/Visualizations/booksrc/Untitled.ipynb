# %%
import numpy as np
import matplotlib.pyplot as plt
import datetime

data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],

        ]

columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]

values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
colors = plt.cm.BuPu(np.linspace(0, 0.5, len(rows)))
n_rows = len(data)

index = [datetime.datetime.now() + datetime.timedelta(hours=i*10) for i in range(len(columns))]
# index = np.arange(len(columns)) + 0.3
bar_width = 0.1
# print(index)
# Initialize the vertical-offset for the stacked bar chart.
y_offset = np.zeros(len(columns))

# Plot bars and create text labels for the table
cell_text = []
for row in range(n_rows):
    plt.bar(index, data[row], bar_width, bottom=y_offset, color=colors[row])
    y_offset = y_offset + data[row]



plt.ylabel("Loss in ${0}'s".format(value_increment))
plt.yticks(values * value_increment, ['%d' % val for val in values])
# plt.xticks([])
plt.title('Loss by Disaster')
plt.gcf().autofmt_xdate()

plt.show()

# %%
from matplotlib import pyplot as plt
import numpy as np

plt.figure()          
N = 5
menMeans = (20, 35, 30, 35, 27)
menStd = (2, 3, 4, 1, 2)
width = 0.35       # the width of the bars
womenMeans = (25, 32, 34, 20, 25)
womenStd = (3, 5, 2, 3, 3)    
ind = np.arange(N)
plt.ylim(0.0, 65.0)
plt.bar(ind, menMeans, width, color='r', yerr=menStd, label='Men means')
plt.bar(ind+width, womenMeans, width, color='y', yerr=womenStd, label='Women means')
plt.ylabel('Bar plot')      

x = np.linspace(0, N)
y = np.sin(x)
axes2 = plt.twinx()
axes2.plot(x, y, color='k', label='Sine')
axes2.set_ylim(-1, 1)
axes2.set_ylabel('Line plot')

plt.show()

# %%
import datetime
import random
import matplotlib.pyplot as plt

# make up some data
x = [datetime.datetime.now() + datetime.timedelta(hours=i) for i in range(12)]
y = [i+random.gauss(0,1) for i,_ in enumerate(x)]

# plot
plt.plot(x,y)
# beautify the x-labels
plt.gcf().autofmt_xdate()

plt.show()

# %%
my_cmaps[0](200)
# Out:
# (0.12156862745098039, 0.4666666666666667, 0.7058823529411765, 0.1)

# %%
normalize([0,100,20])
# Out:
# masked_array(data=[0. , 1. , 0.2],
#              mask=False,
#        fill_value=1e+20)

# %%
vmin, vmax = 0, 3
normalize = Normalize(vmin=vmin, vmax=vmax)

# %%
normalize([0,1,2,3])
# Out:
# masked_array(data=[0.        , 0.33333333, 0.66666667, 1.        ],
#              mask=False,
#        fill_value=1e+20)

# %%
1-normalize([0,1,2,3])
# Out:
# masked_array(data=[1.        , 0.66666667, 0.33333333, 0.        ],
#              mask=False,
#        fill_value=1e+20)

# %%
my_cmaps[0]

# %%
import numpy as np
import matplotlib.pyplot as plt
# colors=plt.get_cmap('tab10')
# list(colors)
from nna import visutils
from matplotlib.colors import Normalize
# columns = x_multi_label

# Create some mock data
t = x_multi_label
t_old = np.arange(1, len(t)+1, 1)

data2 = np.exp(t_old)
data1 = np.sin(2 * np.pi * t_old)

fig, ax1 = plt.subplots(figsize=(15,15))

color = 'tab:red'
ax1.set_xlabel('time (s)')
ax1.set_ylabel('exp', color=color)
ax1.plot(t, data1, color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

data = y_multi_labels


# rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]

values = np.arange(0, 2500, 500)
value_increment = 1000

# Get some pastel shades for the colors
# colors = plt.cm.BuPu(np.linspace(0.1, 1, (10)))
# colors=plt.get_cmap('tab10')(np.arange(10, dtype=int))

cmap = plt.cm.tab20
aCmap = cmap
my_cmaps = visutils.add_normal_dist_alpha(aCmap,alpha_range=[0,1])

vmin, vmax = 0, 3
normalize = Normalize(vmin=vmin, vmax=vmax)

            
            
n_rows = len(data)

# index = np.arange(len(columns)) + 0.3
bar_width = 0.03
# print(index)
# Initialize the vertical-offset for the stacked bar chart.
# y_offset = np.zeros(0,10)

# Plot bars and create text labels for the table
cell_text = []
data=np.array(data)
# data[0:1]=np.ones(10)
y_offset = list(range(len(letters)))

for row in range(n_rows):
#     y_offset=np.cumsum(data[row])-data[row]
#     y_offset[y_offset<0]=0
    colors = [my_cmaps[color_indexes[i]](1-normalize(3)) for i,v in enumerate(data[row])]
    ax2.bar(t[row], 1, bar_width, bottom=y_offset, color=colors)
#     print(t[row],row,data[row],y_offset)

#     y_offset = y_offset + data[row]
import matplotlib.patches as mpatches

patchList = []
for label,color_i in classname2colorindex.items():
    data_key = mpatches.Patch(color=my_cmaps[color_i](3), label=label)
    patchList.append(data_key)


plt.legend(handles=patchList)
# plt.savefig('legend.png', bbox_inches='tight')

fig.tight_layout()  # otherwise the right y-label is slightly clipped
plt.show()

# %%
file_properties_df_path = '/scratch/enis/data/nna/database/allFields_dataV4.pkl'

# %%
import pandas as pd

# %%
asd=pd.read_pickle(file_properties_df_path)

# %%
asd[asd.region=='dempster']
# Out:
#                                                    site_id locationId  \
# /tank/data/nna/real/dempster/21/2019/S4A10357_2...      21         21
# /tank/data/nna/real/dempster/13/2019/S4A10324_2...      13         13
# /tank/data/nna/real/dempster/13/2019/S4A10324_2...      13         13
# /tank/data/nna/real/dempster/23/2019/S4A10347_2...      23         23
# /tank/data/nna/real/dempster/14/2019/S4A10424_2...      14         14
# ...                                                    ...        ...
# /tank/data/nna/real/dempster/14/2019/S4A10424_2...      14         14
# /tank/data/nna/real/dempster/23/2019/S4A10347_2...      23         23
# /tank/data/nna/real/dempster/20/2019/S4A10444_2...      20         20
# /tank/data/nna/real/dempster/23/2019/S4A10347_2...      23         23
# /tank/data/nna/real/dempster/20/2019/S4A10444_2...      20         20
#
#                                                    site_name recorderId  \
# ...
